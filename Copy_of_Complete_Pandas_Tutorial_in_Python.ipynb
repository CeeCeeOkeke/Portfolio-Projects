# %% [markdown]
# <a href="https://colab.research.google.com/github/CeeCeeOkeke/PortfolioProject/blob/main/Copy_of_Complete_Pandas_Tutorial_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the data from CSV file to a Pandas Dataframe

# %%
#importing the pandas library
import pandas as pd
import numpy as np

# %%
#csv file to pandas df
diabetes_df = pd.read_csv('/diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading the data from a excel to a Pandas DataFrame :
# pd.read_excel('file path')

# %%
import pandas as pd

# %%
Nashville_df = pd.read_excel('/NashvilleHousing.xlsx')

# %%
type(Nashville_df)
# Out:
# pandas.core.frame.DataFrame

# %%
Nashville_df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress   SaleDate  SalePrice    LegalReference  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  20130412-0036474
# 1  1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  20140619-0053768
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  20160927-0101718
# 3  1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  20160129-0008913
# 4  1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  20141015-0095255
#
#   SoldAsVacant                           OwnerName  \
# 0           No           FRAZIER, CYRENTHA LYNETTE
# 1           No             BONER, CHARLES & LESLIE
# 2           No           WILSON, JAMES E. & JOANNE
# ...

# %%
Nashville_df.shape
# Out:
# (57951, 19)

# %%
Nashville_df.tail()
# Out:
#        UniqueID          ParcelID        LandUse  \
# 57946      43127  042 07 0 040.00  SINGLE FAMILY
# 57947      46929  042 07 0 042.00  SINGLE FAMILY
# 57948      22766  042 07 0 043.00  SINGLE FAMILY
# 57949      10789  042 07 0 048.00  SINGLE FAMILY
# 57950      15576  042 07 0 049.00  SINGLE FAMILY
#
#                      PropertyAddress   SaleDate  SalePrice    LegalReference  \
# 57946  711  N GRAYCROFT AVE, MADISON 2016-01-04     243000  20160106-0001174
# 57947   707 N GRAYCROFT AVE, MADISON 2016-04-28     279900  20160505-0044436
# 57948  705  N GRAYCROFT AVE, MADISON 2014-10-24     199900  20141030-0100091
# 57949   108  MORNINGVIEW CT, MADISON 2013-12-13     271900  20131217-0127556
# 57950   106  MORNINGVIEW CT, MADISON 2014-05-23     177000  20140602-0047252
#
#       SoldAsVacant                               OwnerName  \
# 57946           No        HUNTER, THOMAS E. & ELIZABETH M.
# 57947           No     DURAI, HEATHER HOLLIS & CHRISTOPHER
# ...

# %% [markdown]
# Exporting  a DataFrame to CSV file :  Dataframe.to('fileName.csv')

# %%
Nashville_df.to_csv('Nashville.xlsx')

# %% [markdown]
# Exporting the Pandas DataFrame to an excel file:
# mention the dataframe nane then df.to_excel('fileName')

# %%
# creating a DataFrame with random values
import numpy as np
random_df = pd.DataFrame(np.random.rand(20, 10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.448837  0.442231  0.272570  0.679772  0.412603  0.816595  0.709120
# 1  0.941207  0.754529  0.042618  0.389295  0.227497  0.102217  0.318173
# 2  0.504405  0.676442  0.844461  0.979947  0.854448  0.205020  0.170521
# 3  0.917625  0.338905  0.627467  0.530032  0.786205  0.781201  0.695087
# 4  0.210033  0.865180  0.036687  0.754223  0.523966  0.776002  0.684875
#
#           7         8         9
# 0  0.009093  0.999765  0.673146
# 1  0.317789  0.718143  0.663426
# 2  0.840081  0.528154  0.681283
# 3  0.308057  0.288102  0.482905
# 4  0.634779  0.301395  0.651470

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# Inspecting a DataFrame

# %%
# finding the number of rows and columns
Nashville_df.shape
# Out:
# (57951, 19)

# %%
#First 30 rows in NashVille_df
Nashville_df.head(30)
# Out:
#     UniqueID           ParcelID            LandUse  \
# 0        2045   007 00 0 125.00      SINGLE FAMILY
# 1       16918   007 00 0 130.00      SINGLE FAMILY
# 2       54582   007 00 0 138.00      SINGLE FAMILY
# 3       43070   007 00 0 143.00      SINGLE FAMILY
# 4       22714   007 00 0 149.00      SINGLE FAMILY
# 5       18367   007 00 0 151.00      SINGLE FAMILY
# 6       19804   007 14 0 002.00      SINGLE FAMILY
# 7       54583   007 14 0 024.00      SINGLE FAMILY
# 8       36500   007 14 0 026.00      SINGLE FAMILY
# 9       19805   007 14 0 034.00      SINGLE FAMILY
# 10      29467  007 14 0A 024.00      SINGLE FAMILY
# 11      10754  007 14 0A 027.00      SINGLE FAMILY
# 12      34751  007 14 0B 010.00  RESIDENTIAL CONDO
# 13       4512   007 15 0 002.00      SINGLE FAMILY
# 14      16919   007 15 0 003.00      SINGLE FAMILY
# 15      16920   007 15 0 004.00      SINGLE FAMILY
# 16      51967   007 15 0 008.00      SINGLE FAMILY
# ...

# %%
#Information about the DataFrame
Nashville_df.info
# Out:
# <bound method DataFrame.info of        UniqueID          ParcelID        LandUse  \
# 0           2045  007 00 0 125.00  SINGLE FAMILY
# 1          16918  007 00 0 130.00  SINGLE FAMILY
# 2          54582  007 00 0 138.00  SINGLE FAMILY
# 3          43070  007 00 0 143.00  SINGLE FAMILY
# 4          22714  007 00 0 149.00  SINGLE FAMILY
# ...          ...              ...            ...
# 57946      43127  042 07 0 040.00  SINGLE FAMILY
# 57947      46929  042 07 0 042.00  SINGLE FAMILY
# 57948      22766  042 07 0 043.00  SINGLE FAMILY
# 57949      10789  042 07 0 048.00  SINGLE FAMILY
# 57950      15576  042 07 0 049.00  SINGLE FAMILY
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 1      1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# 2      1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000
# 3      1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000
# ...

# %%
# Finding the number of missing values
diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#Counting the values based on the labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
# grouping the values based on the mean
diabetes_df.groupby("Outcome").mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical Measures

# %%
#count or number of values tells the nuber of values we are having in each column
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
# Mean value column wise
Nashville_df.mean()
# Out:
# <ipython-input-75-e6447c7444ad>:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Nashville_df.mean()
# <ipython-input-75-e6447c7444ad>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Nashville_df.mean()
# UniqueID          28376.793032
# SalePrice        324736.765026
# Acreage               0.508185
# LandValue         67765.973602
# BuildingValue    159070.663853
# TotalValue       229363.072613
# YearBuilt          1964.001679
# Bedrooms              3.089364
# FullBath              1.881934
# HalfBath              0.282303
# dtype: float64

# %%
#Standard Deviation - column wise
diabetes_df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
# Minimum value
Nashville_df.min()
# Out:
# <ipython-input-79-6eff72f75483>:2: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Nashville_df.min()
# UniqueID                                              0
# ParcelID                                007 00 0 125.00
# LandUse          APARTMENT: LOW RISE (BUILT SINCE 1960)
# SaleDate                            2013-01-02 00:00:00
# SalePrice                                            50
# SoldAsVacant                                          N
# Acreage                                            0.01
# LandValue                                         100.0
# BuildingValue                                       0.0
# TotalValue                                        100.0
# YearBuilt                                        1799.0
# ...

# %%
#Max value
Nashville_df.max()
# Out:
# <ipython-input-81-1df86b691a83>:2: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Nashville_df.max()
# UniqueID                       56635
# ParcelID            188 10 0A 122.00
# LandUse                ZERO LOT LINE
# SaleDate         2019-12-13 00:00:00
# SalePrice                   54278060
# SoldAsVacant                     Yes
# Acreage                       160.06
# LandValue                  2772000.0
# BuildingValue             12971800.0
# TotalValue                13940400.0
# YearBuilt                     2017.0
# Bedrooms                        11.0
# FullBath                        10.0
# HalfBath                         3.0
# dtype: object

# %%
# we can get all the statiscal measures about the data in one goal
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# applying the above describe function to NAshvilleHousing
Nashville_df.describe()
# Out:
#           UniqueID      SalePrice       Acreage     LandValue  BuildingValue  \
# count  57951.000000  5.795100e+04  26896.000000  2.689600e+04   2.689600e+04
# mean   28376.793032  3.247368e+05      0.508185  6.776597e+04   1.590707e+05
# std    16340.805119  9.187482e+05      1.552892  1.045455e+05   2.037719e+05
# min        0.000000  5.000000e+01      0.010000  1.000000e+02   0.000000e+00
# 25%    14258.500000  1.350000e+05      0.180000  2.110000e+04   7.640000e+04
# 50%    28405.000000  2.043000e+05      0.270000  2.820000e+04   1.109000e+05
# 75%    42553.500000  3.250000e+05      0.460000  5.850000e+04   1.780000e+05
# max    56635.000000  5.427806e+07    160.060000  2.772000e+06   1.297180e+07
#
#          TotalValue     YearBuilt      Bedrooms      FullBath      HalfBath
# count  2.689600e+04  25016.000000  25010.000000  25130.000000  24998.000000
# mean   2.293631e+05   1964.001679      3.089364      1.881934      0.282303
# ...

# %% [markdown]
# Manipulating a DataFrame

# %%
# Adding a column to our DataFrame
#Nashville_df['ParcelID'] = Nashville_df.LandValue

#Removing a row
Nashville_df.drop(index=0, axis = 1)
# Out:
#        UniqueID          ParcelID        LandUse  \
# 1          16918  007 00 0 130.00  SINGLE FAMILY
# 2          54582  007 00 0 138.00  SINGLE FAMILY
# 3          43070  007 00 0 143.00  SINGLE FAMILY
# 4          22714  007 00 0 149.00  SINGLE FAMILY
# 5          18367  007 00 0 151.00  SINGLE FAMILY
# ...          ...              ...            ...
# 57946      43127  042 07 0 040.00  SINGLE FAMILY
# 57947      46929  042 07 0 042.00  SINGLE FAMILY
# 57948      22766  042 07 0 043.00  SINGLE FAMILY
# 57949      10789  042 07 0 048.00  SINGLE FAMILY
# 57950      15576  042 07 0 049.00  SINGLE FAMILY
#
#                           PropertyAddress   SaleDate  SalePrice  \
# 1      1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# 2      1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000
# 3      1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000
# 4      1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000
# ...

# %%
#drop a column
Nashville_df.drop(columns= "LandUse", axis = 1)
# Out:
#        UniqueID          ParcelID                     PropertyAddress  \
# 0           2045  007 00 0 125.00  1808  FOX CHASE DR, GOODLETTSVILLE
# 1          16918  007 00 0 130.00  1832  FOX CHASE DR, GOODLETTSVILLE
# 2          54582  007 00 0 138.00  1864 FOX CHASE  DR, GOODLETTSVILLE
# 3          43070  007 00 0 143.00  1853  FOX CHASE DR, GOODLETTSVILLE
# 4          22714  007 00 0 149.00  1829  FOX CHASE DR, GOODLETTSVILLE
# ...          ...              ...                                 ...
# 57946      43127  042 07 0 040.00       711  N GRAYCROFT AVE, MADISON
# 57947      46929  042 07 0 042.00        707 N GRAYCROFT AVE, MADISON
# 57948      22766  042 07 0 043.00       705  N GRAYCROFT AVE, MADISON
# 57949      10789  042 07 0 048.00        108  MORNINGVIEW CT, MADISON
# 57950      15576  042 07 0 049.00        106  MORNINGVIEW CT, MADISON
#
#         SaleDate  SalePrice    LegalReference SoldAsVacant  \
# 0     2013-04-09     240000  20130412-0036474           No
# ...

# %%
# Locating a row usimg the index value
Nashville_df.iloc[34]
# Out:
# UniqueID                                            54584
# ParcelID                                  012 03 0 013.00
# LandUse                                     SINGLE FAMILY
# PropertyAddress        604 SUNNYSLOPE  CT, GOODLETTSVILLE
# SaleDate                              2016-09-23 00:00:00
# SalePrice                                          228000
# LegalReference                           20160927-0101636
# SoldAsVacant                                           No
# OwnerName                                RED THUNDER, LLC
# OwnerAddress       604  SUNNYSLOPE CT, GOODLETTSVILLE, TN
# Acreage                                              1.01
# TaxDistrict                     GENERAL SERVICES DISTRICT
# LandValue                                         40000.0
# BuildingValue                                    143300.0
# TotalValue                                       183300.0
# YearBuilt                                          1973.0
# ...

# %%
#locating a particular column
print(Nashville_df.iloc[1, 3]) #print first column of dataframe
print(Nashville_df.iloc[1, -5])
# Out:
# 1832  FOX CHASE DR, GOODLETTSVILLE
# 319000.0

# %% [markdown]
# Correlation
# 1. Positive Correlation
# 2. Negative Correlation

# %%
Nashville_df.corr()
# Out:
# <ipython-input-99-f592380635a7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Nashville_df.corr()
#                UniqueID   SalePrice   Acreage  LandValue  BuildingValue  \
# UniqueID        1.000000   0.017511  0.000764  -0.054439      -0.079752
# SalePrice       0.017511   1.000000  0.198445   0.605040       0.575746
# Acreage         0.000764   0.198445  1.000000   0.292778       0.124960
# LandValue      -0.054439   0.605040  0.292778   1.000000       0.517348
# BuildingValue  -0.079752   0.575746  0.124960   0.517348       1.000000
# TotalValue     -0.080267   0.662919  0.207265   0.766506       0.945674
# YearBuilt       0.005733   0.034016  0.018962  -0.019055       0.191571
# Bedrooms       -0.039626   0.369970  0.148750   0.338334       0.444280
# ...

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
